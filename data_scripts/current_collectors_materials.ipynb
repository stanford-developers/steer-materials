# %%
from steer_core.DataManager import DataManager
from steer_materials.CellMaterials.Base import CurrentCollectorMaterial
from steer_opencell_design import __version__

from datetime import datetime as dt
import pandas as pd

# %%
db = DataManager()

# %%
db.get_table_names()
# Out:
# ['cells',
#  'current_collector_materials',
#  'insulation_materials',
#  'separator_materials',
#  'anode_materials',
#  'binder_materials',
#  'cathode_materials',
#  'conductive_additive_materials']

# %%
db.drop_table('current_collector_materials')

# %%
db.create_table(table_name='current_collector_materials', columns={
    'name': 'TEXT',
    'object': 'TEXT',
    'date': 'TEXT',
    'version': 'TEXT'
})

# %%
# materials 

aluminum = CurrentCollectorMaterial(
    name='Aluminum', 
    density=2.70, 
    specific_cost=12.3, 
    color='#C0C0C0'
)

copper = CurrentCollectorMaterial(
    name='Copper', 
    density=8.96, 
    specific_cost=18.1, 
    color='#B87333'
)

materials = [aluminum, copper]
pickled_materials = [m.serialize() for m in materials]

# %%
aluminum.specific_cost_range
# Out:
# (6.15, 24.6)

# %%
# store data for current collectors

db.insert_data(table_name='current_collector_materials', data=pd.DataFrame({
    'name': [m.name for m in materials],
    'object': pickled_materials,
    'date': [m.last_updated for m in materials],
    'version': [__version__ for m in materials],
}))

# %%
db.get_current_collector_materials(most_recent=False)
# Out:
#        name                                             object  \
# 0  Aluminum  gASVKAEAAAAAAACMInN0ZWVyX21hdGVyaWFscy5DZWxsTW...
# 1    Copper  gASVJgEAAAAAAACMInN0ZWVyX21hdGVyaWFscy5DZWxsTW...
#
#                   date version
# 0  2025-09-30 09:12:04  0.3.10
# 1  2025-09-30 09:12:04  0.3.10

# %%
db.get_current_collector_materials()
# Out:
#        name                                             object  \
# 0  Aluminum  gASVKAEAAAAAAACMInN0ZWVyX21hdGVyaWFscy5DZWxsTW...
# 1    Copper  gASVJgEAAAAAAACMInN0ZWVyX21hdGVyaWFscy5DZWxsTW...
#
#                   date version
# 0  2025-09-30 09:12:04  0.3.10
# 1  2025-09-30 09:12:04  0.3.10
